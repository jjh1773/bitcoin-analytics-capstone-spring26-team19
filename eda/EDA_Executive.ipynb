# %% [markdown]
# # Executive Summary: Bitcoin & Polymarket Deep EDA
#
# This notebook summarizes the key strategic findings from our Exploratory Data Analysis. It focuses on identifying leading indicators and risk metrics to optimize the Dollar Cost Averaging (DCA) strategy.
#
# ---

# %% [markdown]
# ## 1. Market Valuation & Risk Depth
#
# ### 1.1 MVRV Distribution (Value Zones)
# The MVRV Ratio serves as a primary indicator for market overheating.
# - **Mean/Median:** Historically, the MVRV fluctuates around **1.6 - 1.7**.
# - **Strategic Buy Zone:** Values below **1.0** are rare and represent high-probability accumulation zones.
# - **Danger Zone:** Values exceeding **3.0** indicate extreme overvaluation.

# %%
from IPython.display import Image, display
display(Image(filename='figures/mvrv_distribution.png'))

# %% [markdown]
# ### 1.2 Drawdown Analysis (Risk Depth)
# Understanding the "Pain Threshold" is critical for capital preservation.
# - Bitcoin frequently experiences drawdowns of **-50% to -80%** during bear cycles.
# - Current price retreat levels compared with these historical benchmarks help define our "Risk Regime" (Low, Mid, High pain).

# %%
display(Image(filename='figures/btc_drawdown.png'))

# %% [markdown]
# ## 2. Standardized Multi-Metric Comparison
#
# By converting Price, HashRate, and MVRV into **Z-Scores**, we can compare their relative momentum despite different scales.
# - **Fundamental Divergence:** We observe periods where HashRate (Network Security) continues to grow while Price Z-Score remains stagnant or declines, often highlighting a fundamental bottoming process.

# %%
display(Image(filename='figures/standardized_comparison.png'))

# %% [markdown]
# ## 3. Polymarket Activity as a Leading Indicator
#
# The most significant discovery of this EDA is the **Lead-Lag relationship** between Polymarket sentiment and Bitcoin price.
#
# - **Prediction Precedence:** Cross-correlation peaks at a **-5 to -10 day lag**.
# - **Actionable Insight:** Spikes in Bitcoin-related market creations on Polymarket serve as a **5-10 day leading signal** for upcoming price volatility.
# - **Strategy Implementation:** This metric will be used to front-run DCA weight adjustments before major sentiment shifts are priced into the spot market.

# %%
display(Image(filename='figures/lead_lag_correlation.png'))

# %% [markdown]
# ---
# **Next Steps:** Integrate these four core metrics (MVRV, Drawdown, Z-Score Divergence, and Poly-Lag) into the finalized algorithmic DCA backbone.
